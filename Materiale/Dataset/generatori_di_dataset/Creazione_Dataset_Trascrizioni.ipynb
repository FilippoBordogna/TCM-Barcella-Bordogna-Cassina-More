# %% [markdown]
# Carico da google drive gli id ed i Lorem Ipsum

# %%
from google.colab import drive
drive.mount('/content/drive')

import random
import csv

with open('transcriptions.csv', 'w', newline='') as csv_file:
    writer = csv.writer(file)
    column = ['id', 'language', 'abbreviation', 'phrase']
    writer = csv.DictWriter(csv_file, fieldnames=column)
    writer.writeheader()

    file_id=pd.read_csv('drive/My Drive/Colab Notebooks/dataset/id.csv')
    file_languages=pd.read_csv('drive/My Drive/Colab Notebooks/dataset/languages.csv')

    for index, row in file_id.iterrows():
        #print(row.idx)
        n_languages=random.randint(1,8)
        i=0
        for ind, r in file_languages.iterrows():
          writer.writerow({'id': row.idx, 'language': r.language, 'abbreviation': r.abbreviation, 'phrase': 'Questa è solo una frase di prova'})
          if(i>n_languages):
            break
          else:
            i=i+1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
